# %%
base = (0.140*pow(6,2.60))* 1500
agb_est = base / 1000
agb_est
# Out:
# 22.151979749971424

# %%
a = 0.110
b=2.60
c = 1500 /1000
agb_est=(a * pow(20,b))*c
agb_est
# Out:
# 398.2556382119809

# %%
import pandas as pd

pd.read_parquet("../top20_df.parquet",)
# Out:
#     final_rank                     source_doc_id  final_score  \
# 0            1  part13__source-document06022.txt     0.758424
# 1            2  part19__source-document09499.txt     0.352541
# 2            3  part23__source-document11043.txt     0.347547
# 3            4   part5__source-document02369.txt     0.340948
# 4            5   part2__source-document00960.txt     0.339745
# 5            6  part20__source-document09976.txt     0.333800
# 6            7  part10__source-document04659.txt     0.332084
# 7            8   part8__source-document03762.txt     0.330781
# 8            9  part21__source-document10481.txt     0.329963
# 9           10  part18__source-document08528.txt     0.327431
# 10          11   part5__source-document02066.txt     0.324826
# 11          12   part8__source-document03889.txt     0.324806
# 12          13  part20__source-document09917.txt     0.317979
# 13          14  part14__source-document06826.txt     0.316692
# ...
