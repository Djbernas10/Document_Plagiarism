# %%
import pandas as pd

pd.read_parquet("../../top20_df.parquet")
# Out:
#    final_rank                     source_doc_id  final_score  \
# 0           1  part13__source-document06022.txt     0.758424
# 1           2  part19__source-document09499.txt     0.352541
# 2           3  part23__source-document11043.txt     0.347547
# 3           4   part5__source-document02369.txt     0.340948
# 4           5   part2__source-document00960.txt     0.339745
#
#    weighted_mean_score  weighted_max_score  methods_found_count  \
# 0             0.461500            0.885678                    4
# 1             0.295478            0.376996                    3
# 2             0.302677            0.366777                    3
# 3             0.303342            0.357064                    2
# 4             0.296005            0.358491                    1
#
#    found_by_tfidf  found_by_esa  found_by_lsa  found_by_emb  ...  \
# 0            True          True          True          True  ...
# 1            True          True         False          True  ...
# 2            True          True         False          True  ...
# 3            True         False         False          True  ...
# 4           False         False         False          True  ...
#
#    lsa_mean_rank  lsa_match_count  lsa_unique_source_chunks  \
# 0            1.0            279.0                     192.0
# 1            NaN              NaN                       NaN
# 2            NaN              NaN                       NaN
# 3            NaN              NaN                       NaN
# 4            NaN              NaN                       NaN
#
#    lsa_unique_suspicious_chunks         lsa_source_relative_path  \
# 0                           9.0  part13/source-document06022.txt
# 1                           NaN                             None
# 2                           NaN                             None
# 3                           NaN                             None
# 4                           NaN                             None
#
#    emb_mean_rank  emb_match_count  emb_unique_source_chunks  \
# 0            1.0            159.0                     132.0
# 1            8.0             70.0                      65.0
# 2           12.0             25.0                      21.0
# 3            6.0             13.0                       9.0
# 4            2.0             12.0                      11.0
#
#    emb_unique_suspicious_chunks         emb_source_relative_path
# 0                           9.0  part13/source-document06022.txt
# 1                           4.0  part19/source-document09499.txt
# 2                           3.0  part23/source-document11043.txt
# 3                           3.0   part5/source-document02369.txt
# 4                           2.0   part2/source-document00960.txt
#
# [5 rows x 38 columns]

# %%
from ollama import chat

stream = chat(
  model='qwen3.5:0.8b',
  messages=[{'role': 'user', 'content': 'Respond with ONLY a JSON object,What is 17 × 23?'}],
  stream=True,
)

in_thinking = False
content = ''
thinking = ''
for chunk in stream:
  if chunk.message.thinking:
    if not in_thinking:
      in_thinking = True
      print('Thinking:\n', end='', flush=True)
    print(chunk.message.thinking, end='', flush=True)
    # accumulate the partial thinking 
    thinking += chunk.message.thinking
  elif chunk.message.content:
    if in_thinking:
      in_thinking = False
      print('\n\nAnswer:\n', end='', flush=True)
    print(chunk.message.content, end='', flush=True)
    # accumulate the partial content
    content += chunk.message.content

  # append the accumulated fields to the messages for the next request
  new_messages = [{ "role": 'assistant', "thinking": thinking, "content": content }]
# Out:
# Thinking:
# Thinking Process:
#
# 1.  **Analyze the Request:**
#     *   Input: "Respond with ONLY a JSON object,What is 17 × 23?"
#     *   Task: Calculate the product of 17 and 23.
#     *   Constraint: Output must be *only* a JSON object. No markdown formatting (like ```json ... ```), no explanatory text, no introductory phrases.
#
# 2.  **Perform Calculation:**
#     *   $17 \times 23$
#     *   $17 \times 20 = 340$
#     *   $17 \times 3 = 51$
#     *   $340 + 51 = 391$
#     *   Alternatively: $10 \times 23 = 230$, $7 \times 23 = 161$. $230 + 161 = 391$.
#
# 3.  **Format Output:**
#     *   JSON structure: `{ "answer": 391 }` or `{ "result": 391 }` or similar.
#     *   Ensure no extra whitespace or text outside the JSON block.
#     *   The prompt asks for "ONLY a JSON object".
#
# 4.  **Construct JSON:**
#     *   `{ "answer": 391 }`
#
# 5.  **Review Constraints:**
#     *   "Respond with ONLY a JSON object"
#     *   "What is 17 × 23?" is the question inside the prompt.
#     *   Must not include markdown code fences (```) unless the system instruction implies it's okay, but usually "ONLY a JSON object" means raw JSON text. However, often in these interfaces, wrapping in ```json is acceptable but strictly speaking, raw JSON is safer for "ONLY". I will output raw JSON text to be safe.
#     *   Wait, looking at common behavior for this specific instruction type: usually, it means raw text that parses as JSON.
#     *   Let's keep it simple: `{ "answer": 391 }`
#
# 6.  **Final Check:**
#     *   Is it valid JSON? Yes.
#     *   Is there any extra text? No.
#     *   Is the calculation correct? Yes (391).
#
#     *Self-Correction on Markdown:* If I output ```json ... ```, that includes markdown characters, not just a JSON object. The instruction says "Respond with ONLY a JSON object". So I should output the raw string representation of the JSON.
#
#     *Decision:* Output `{"answer": 391}`.
#
#     *Wait, one more check:* Sometimes users expect a specific key. I'll use "answer" or "result". "answer" is standard.
#
#     *Final Plan:* Print `{"answer": 391}`.
#
#     *Wait, re-reading the prompt:* "Respond with ONLY a JSON object,What is 17 × 23?"
#     There is a comma after "object". It's a bit messy. "Respond with ONLY a JSON object, [then] What is 17 × 23?"
#     Actually, it looks like a single prompt string: "Respond with ONLY a JSON object,What is 17 × 23?"
#     The intent is clear: Answer the math question in JSON.
#
#     *Final Output:* `{"answer": 391}`
#
# Answer:
# {"answer": 391}
