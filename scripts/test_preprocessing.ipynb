# %%
from pathlib import Path
from preprocessing import full_preprocessing_pipeline

full_preprocessing_pipeline(
    SOURCE_FOLDER=Path("../datasets/PAN2011/usable/source-document"),
    SUSPICIOUS_FOLDER=Path("../datasets/PAN2011/usable/suspicious-document"),
    OUTPUT_DIR=Path("../datasets/processed/PAN2011_500"),
    batch_size=300,
    chunk_size=500,
    overlap=100,
    min_words=120,
)
# Out:
# Collecting source documents...
# Found 11093 .txt files in ..\datasets\PAN2011\usable\source-document
# [1/11093] Reading: part1/source-document00001.txt
# [500/11093] Reading: part1/source-document00500.txt
# [1000/11093] Reading: part10/source-document05000.txt
# [1500/11093] Reading: part11/source-document05500.txt
# [2000/11093] Reading: part12/source-document06000.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from pathlib import Path
#       2 from preprocessing import full_preprocessing_pipeline
#       3
# ----> 4 full_preprocessing_pipeline(
#       5     SOURCE_FOLDER=Path("../datasets/PAN2011/usable/source-document"),
#       6     SUSPICIOUS_FOLDER=Path("../datasets/PAN2011/usable/suspicious-document"),
#       7     OUTPUT_DIR=Path("../datasets/processed/PAN2011_500"),
#
# File c:\projects\thesis\Document_Plagiarism\scripts\preprocessing.py:595, in full_preprocessing_pipeline(SOURCE_FOLDER, SUSPICIOUS_FOLDER, OUTPUT_DIR, batch_size, chunk_size, overlap, min_words)
#     592 suspicious_embeddings_path = OUTPUT_DIR / "suspicious_chunks_embeddings.parquet"
#     594 # 1. Raw documents -> document Parquet
# --> 595 source_doc_processing(
#     596     SOURCE_FOLDER=SOURCE_FOLDER,
#     597     SUSPICIOUS_FOLDER=SUSPICIOUS_FOLDER,
#     598     SOURCE_OUTPUT=source_documents_path,
#     599     SUSPICIOUS_OUTPUT=suspicious_documents_path,
#     600     batch_size=batch_size,
#     601 )
#     603 # 2. Document Parquet -> canonical chunks
#     604 print("\nBuilding source chunks...")
#
# File c:\projects\thesis\Document_Plagiarism\scripts\preprocessing.py:533, in source_doc_processing(SOURCE_FOLDER, SUSPICIOUS_FOLDER, SOURCE_OUTPUT, SUSPICIOUS_OUTPUT, batch_size)
#     525 def source_doc_processing(
#     526     SOURCE_FOLDER,
#     527     SUSPICIOUS_FOLDER,
#    (...)    530     batch_size: int = 250,
#     531 ):
#     532     print("Collecting source documents...")
# --> 533     source_count = collect_documents_to_parquet(
#     534         SOURCE_FOLDER,
#     535         SOURCE_OUTPUT,
#     536         batch_size=batch_size,
#     537     )
#     539     print("\nCollecting suspicious documents...")
#     540     suspicious_count = collect_documents_to_parquet(
#     541         SUSPICIOUS_FOLDER,
#     542         SUSPICIOUS_OUTPUT,
#     543         batch_size=batch_size,
#     544     )
#
# File c:\projects\thesis\Document_Plagiarism\scripts\preprocessing.py:172, in collect_documents_to_parquet(folder, output_path, batch_size, log_every)
#     169 parts = path.relative_to(folder).parts
#     170 part_name = parts[0] if len(parts) > 1 else None
# --> 172 raw_text = read_text_file(path)
#     173 clean_text = clean_pan_source_text(raw_text)
#     175 batch.append({
#     176     "doc_id": doc_id,
#     177     "file_name": path.name,
#    (...)    188     "clean_word_count": len(clean_text.split()),
#     189 })
#
# File c:\projects\thesis\Document_Plagiarism\scripts\preprocessing.py:112, in read_text_file(path)
#     107 """
#     108 Read PAN text files safely.
#     109 Tries UTF-8 first, then Latin-1 fallback.
#     110 """
#     111 try:
# --> 112     return path.read_text(encoding="utf-8", errors="ignore")
#     113 except Exception:
#     114     return path.read_text(encoding="latin-1", errors="ignore")
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\pathlib.py:1027, in Path.read_text(self, encoding, errors)
#    1023 """
#    1024 Open the file in text mode, read it, and close the file.
#    1025 """
#    1026 encoding = io.text_encoding(encoding)
# -> 1027 with self.open(mode='r', encoding=encoding, errors=errors) as f:
#    1028     return f.read()
#
# File ~\AppData\Roaming\uv\python\cpython-3.12-windows-x86_64-none\Lib\pathlib.py:1013, in Path.open(self, mode, buffering, encoding, errors, newline)
#    1011 if "b" not in mode:
#    1012     encoding = io.text_encoding(encoding)
# -> 1013 return io.open(self, mode, buffering, encoding, errors, newline)
#
# File <frozen codecs>:309, in BufferedIncrementalDecoder.__init__(self, errors)
# --> 309 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:

# %%
from pathlib import Path
from preprocessing import full_preprocessing_pipeline

full_preprocessing_pipeline(
    SOURCE_FOLDER=Path("../datasets/PAN2011/usable/source-document"),
    SUSPICIOUS_FOLDER=Path("../datasets/PAN2011/usable/suspicious-document"),
    OUTPUT_DIR=Path("../datasets/processed/PAN2011_300"),
    batch_size=500,
    chunk_size=300,
    overlap=150,
    min_words=60,
)
# Out:
# Collecting source documents...
# Found 11093 .txt files in ..\datasets\PAN2011\usable\source-document
# [1/11093] Reading: part1/source-document00001.txt
# [500/11093] Reading: part1/source-document00500.txt
# [1000/11093] Reading: part10/source-document05000.txt
# [1500/11093] Reading: part11/source-document05500.txt
# [2000/11093] Reading: part12/source-document06000.txt
# [2500/11093] Reading: part13/source-document06500.txt
# [3000/11093] Reading: part14/source-document07000.txt
# [3500/11093] Reading: part15/source-document07500.txt
# [4000/11093] Reading: part16/source-document08000.txt
# [4500/11093] Reading: part17/source-document08500.txt
# [5000/11093] Reading: part18/source-document09000.txt
# [5500/11093] Reading: part19/source-document09500.txt
# [6000/11093] Reading: part2/source-document01000.txt
# [6500/11093] Reading: part20/source-document10000.txt
# [7000/11093] Reading: part21/source-document10500.txt
# [7500/11093] Reading: part22/source-document11000.txt
# [8000/11093] Reading: part3/source-document01407.txt
# [8500/11093] Reading: part4/source-document01907.txt
# [9000/11093] Reading: part5/source-document02407.txt
# [9500/11093] Reading: part6/source-document02907.txt
# [10000/11093] Reading: part7/source-document03407.txt
# [10500/11093] Reading: part8/source-document03907.txt
# [11000/11093] Reading: part9/source-document04407.txt
# [11093/11093] Reading: part9/source-document04500.txt
# Saved 11093 rows to: ..\datasets\processed\PAN2011_300\source_documents.parquet
#
# Collecting suspicious documents...
# Found 11093 .txt files in ..\datasets\PAN2011\usable\suspicious-document
# [1/11093] Reading: part1/suspicious-document00001.txt
# [500/11093] Reading: part1/suspicious-document00500.txt
# [1000/11093] Reading: part10/suspicious-document05000.txt
# [1500/11093] Reading: part11/suspicious-document05500.txt
# [2000/11093] Reading: part12/suspicious-document06000.txt
# [2500/11093] Reading: part13/suspicious-document06500.txt
# [3000/11093] Reading: part14/suspicious-document07000.txt
# [3500/11093] Reading: part15/suspicious-document07500.txt
# [4000/11093] Reading: part16/suspicious-document08000.txt
# [4500/11093] Reading: part17/suspicious-document08500.txt
# [5000/11093] Reading: part18/suspicious-document09000.txt
# [5500/11093] Reading: part19/suspicious-document09500.txt
# [6000/11093] Reading: part2/suspicious-document01000.txt
# [6500/11093] Reading: part20/suspicious-document10000.txt
# [7000/11093] Reading: part21/suspicious-document10500.txt
# [7500/11093] Reading: part22/suspicious-document11000.txt
# [8000/11093] Reading: part3/suspicious-document01407.txt
# [8500/11093] Reading: part4/suspicious-document01907.txt
# [9000/11093] Reading: part5/suspicious-document02407.txt
# [9500/11093] Reading: part6/suspicious-document02907.txt
# [10000/11093] Reading: part7/suspicious-document03407.txt
# [10500/11093] Reading: part8/suspicious-document03907.txt
# [11000/11093] Reading: part9/suspicious-document04407.txt
# [11093/11093] Reading: part9/suspicious-document04500.txt
# Saved 11093 rows to: ..\datasets\processed\PAN2011_300\suspicious_documents.parquet
#
# Source documents found: 11093
# Suspicious documents found: 11093
#
# Saved source Parquet to: ..\datasets\processed\PAN2011_300\source_documents.parquet
# Saved suspicious Parquet to: ..\datasets\processed\PAN2011_300\suspicious_documents.parquet
#
# Example source document:
# part1/source-document00001.txt
# raw chars: 251039
# clean chars: 250031
# raw words: 43689
# clean words: 43796
# On the 18th, we finished the journey by a nine mile march to Bocking, and there settled down into billets for the rest of our time in England. Though we were spoilt at Harpenden, we are sure that all ranks have nothing but pleasant recollections of the time spent at Braintree and Bocking, where one and all treated us with the greatest kindness, and we hope were sorry to lose us. Where all were so kind it is almost invidious to mention names, but one feels (though they themselves would be the fir
#
# Building source chunks...
# Written chunks so far: 127444
# Written chunks so far: 262086
# Written chunks so far: 409721
# Written chunks so far: 535806
# Written chunks so far: 675086
# Written chunks so far: 808028
# Written chunks so far: 936870
# Written chunks so far: 1065249
# Written chunks so far: 1192970
# Written chunks so far: 1310529
# Written chunks so far: 1445419
# Written chunks so far: 1563179
# Written chunks so far: 1693040
# Written chunks so far: 1804749
# Written chunks so far: 1940252
# Written chunks so far: 2076095
# Written chunks so far: 2197843
# Written chunks so far: 2321591
# Written chunks so far: 2456255
# Written chunks so far: 2578504
# Written chunks so far: 2697500
# Written chunks so far: 2816089
# Written chunks so far: 2842139
# Saved 2842139 chunks to: ..\datasets\processed\PAN2011_300\source_chunks.parquet
#
# Building suspicious chunks...
# Written chunks so far: 87707
# Written chunks so far: 195182
# Written chunks so far: 280761
# Written chunks so far: 376042
# Written chunks so far: 467041
# Written chunks so far: 550234
# Written chunks so far: 637240
# Written chunks so far: 730566
# Written chunks so far: 814702
# Written chunks so far: 902134
# Written chunks so far: 998554
# Written chunks so far: 1095809
# Written chunks so far: 1187661
# Written chunks so far: 1274130
# Written chunks so far: 1357985
# Written chunks so far: 1444858
# Written chunks so far: 1535240
# Written chunks so far: 1626069
# Written chunks so far: 1714320
# Written chunks so far: 1795008
# Written chunks so far: 1892062
# Written chunks so far: 1974730
# Written chunks so far: 1993918
# Saved 1993918 chunks to: ..\datasets\processed\PAN2011_300\suspicious_chunks.parquet
#
# Preparing source LSA/ESA chunks...
# Saved 2842139 LSA/ESA chunks to: ..\datasets\processed\PAN2011_300\source_chunks_lsa_esa.parquet
#
# Preparing suspicious LSA/ESA chunks...
# Saved 1993918 LSA/ESA chunks to: ..\datasets\processed\PAN2011_300\suspicious_chunks_lsa_esa.parquet
#
# Preparing source embedding chunks...
# Saved 2842139 embedding chunks to: ..\datasets\processed\PAN2011_300\source_chunks_embeddings.parquet
#
# Preparing suspicious embedding chunks...
# Saved 1993918 embedding chunks to: ..\datasets\processed\PAN2011_300\suspicious_chunks_embeddings.parquet
#
# Preprocessing complete.
# Output folder: ..\datasets\processed\PAN2011_300
#
# Example source chunk:
#                             chunk_id                           doc_id                 file_name                   relative_path   part  chunk_index                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            chunk_text  start_char  end_char  word_start  word_end  word_count  chunk_size  overlap  min_words
# 0  part1__source-document00001_c0000  part1__source-document00001.txt  source-document00001.txt  part1/source-document00001.txt  part1            0  On the 18th, we finished the journey by a nine mile march to Bocking, and there settled down into billets for the rest of our time in England. Though we were spoilt at Harpenden, we are sure that all ranks have nothing but pleasant recollections of the time spent at Braintree and Bocking, where one and all treated us with the greatest kindness, and we hope were sorry to lose us. Where all were so kind it is almost invidious to mention names, but one feels (though they themselves would be the first to deny it) that a special debt of gratitude is owed to the Nuns of the Convent at Booking, whose kindness and care for those who were billeted at the Convent, and for all with whom they came in contact, were beyond all praise. In order to prepare for any possible German landing on the Essex coast orders had been issued for a series of trenches to be dug to form defensive lines for the protection of London, and we were at once set on to this work, which was pushed on as rapidly as possible, systems of trenches, redoubts, gun positions, and other defensive works being put in hand. Our work was mainly at Panfield, Marks Farm and Black Notley. It was not an ideal season for trench digging, especially in the clay of Essex, which was the "genuine" article, and we were glad when the bulk of it was finished by Christmas. This work was carried out under Royal Engineers' supervision and was in some ways instructive, although we thought that the principles we had been taught in the Military Manuals were frequently violated by the siting of trenches along the sides of prominent hedgerows. Nevertheless, what we did was more after the nature of           0      1652           0       300         300         300      150         60
