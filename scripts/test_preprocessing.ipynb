# %%
from pathlib import Path
from preprocessing import full_preprocessing_pipeline

full_preprocessing_pipeline(
    SOURCE_FOLDER=Path("../datasets/PAN2011/usable/source-document"),
    SUSPICIOUS_FOLDER=Path("../datasets/PAN2011/usable/suspicious-document"),
    OUTPUT_DIR=Path("../datasets/processed/PAN2011"),
    batch_size=250,
    chunk_size=180,
    overlap=50,
    min_words=40,
)
# Out:
# Collecting source documents...
# Found 11093 .txt files in ..\datasets\PAN2011\usable\source-document
# [1/11093] Reading: part1/source-document00001.txt
# [500/11093] Reading: part1/source-document00500.txt
# [1000/11093] Reading: part10/source-document05000.txt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 from pathlib import Path
#       2 from preprocessing import full_preprocessing_pipeline
#       3
# ----> 4 full_preprocessing_pipeline(
#       5     SOURCE_FOLDER=Path("../datasets/PAN2011/usable/source-document"),
#       6     SUSPICIOUS_FOLDER=Path("../datasets/PAN2011/usable/suspicious-document"),
#       7     OUTPUT_DIR=Path("../datasets/processed"),
#
# File c:\projects\thesis\Document_Plagiarism\scripts\preprocessing.py:596, in full_preprocessing_pipeline(SOURCE_FOLDER, SUSPICIOUS_FOLDER, OUTPUT_DIR, batch_size, chunk_size, overlap, min_words)
#     593 suspicious_embeddings_path = OUTPUT_DIR / "suspicious_chunks_embeddings.parquet"
#     595 # 1. Raw documents -> document Parquet
# --> 596 source_doc_processing(
#     597     SOURCE_FOLDER=SOURCE_FOLDER,
#     598     SUSPICIOUS_FOLDER=SUSPICIOUS_FOLDER,
#     599     SOURCE_OUTPUT=source_documents_path,
#     600     SUSPICIOUS_OUTPUT=suspicious_documents_path,
#     601     batch_size=batch_size,
#     602 )
#     604 # 2. Document Parquet -> canonical chunks
#     605 print("\nBuilding source chunks...")
#
# File c:\projects\thesis\Document_Plagiarism\scripts\preprocessing.py:534, in source_doc_processing(SOURCE_FOLDER, SUSPICIOUS_FOLDER, SOURCE_OUTPUT, SUSPICIOUS_OUTPUT, batch_size)
#     526 def source_doc_processing(
#     527     SOURCE_FOLDER,
#     528     SUSPICIOUS_FOLDER,
#    (...)    531     batch_size: int = 250,
#     532 ):
#     533     print("Collecting source documents...")
# --> 534     source_count = collect_documents_to_parquet(
#     535         SOURCE_FOLDER,
#     536         SOURCE_OUTPUT,
#     537         batch_size=batch_size,
#     538     )
#     540     print("\nCollecting suspicious documents...")
#     541     suspicious_count = collect_documents_to_parquet(
#     542         SUSPICIOUS_FOLDER,
#     543         SUSPICIOUS_OUTPUT,
#     544         batch_size=batch_size,
#     545     )
#
# File c:\projects\thesis\Document_Plagiarism\scripts\preprocessing.py:191, in collect_documents_to_parquet(folder, output_path, batch_size, log_every)
#     173 clean_text = clean_pan_source_text(raw_text)
#     175 batch.append({
#     176     "doc_id": doc_id,
#     177     "file_name": path.name,
#    (...)    188     "clean_word_count": len(clean_text.split()),
#     189 })
# --> 191 if len(batch) >= batch_size:
#     192     df = pd.DataFrame(batch)
#     193     table = pa.Table.from_pandas(df, preserve_index=False)
#
# KeyboardInterrupt:
